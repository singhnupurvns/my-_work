# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("insurance_data (1).csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,color = "blue",marker = "+")
plt.xlabel("age")
plt.ylabel("bought_insurance")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(df[["age"]],df["bought_insurance"],test_size = 0.1)

# %%
x_train
# Out:
# 3     52
# 5     56
# 24    50
# 13    29
# 10    18
# 12    27
# 0     22
# 1     25
# 4     46
# 16    25
# 20    21
# 23    45
# 14    49
# 7     60
# 22    40
# 26    23
# 9     61
# 6     55
# 18    19
# 21    26
# 17    58
# 8     62
# 11    28
# 15    55
# Name: age, dtype: int64

# %%
x_test
# Out:
# 25    54
# 19    18
# 2     47
# Name: age, dtype: int64

# %%
log  =  model.fit(x_train,y_train)

# %%
log
# Out:
# LogisticRegression()

# %%
prediction = log.predict([[42]])
# Out:
# C:\Users\abc\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([1], dtype=int64)

# %%
prediction1 = model.predict([[54]])
# Out:
# C:\Users\abc\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction1
# Out:
# array([1], dtype=int64)

# %%
prediction = log.predict([[33]])
# Out:
# C:\Users\abc\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([0], dtype=int64)

# %%
plt.scatter(df.age,df.bought_insurance,color = "blue",marker = "+")
plt.plot(df.age,log.predict(df[["age"]]),color = "red",marker = "*")
plt.xlabel("age")
plt.ylabel("bought_insurance")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(df.age, df.bought_insurance, color="blue", marker="+")

# Predicting and plotting the logistic regression line
plt.plot(df.age, log.predict(df[['age']]), color="red", marker="*")

# Display the plot
plt.xlabel("Age")
plt.ylabel("Bought Insurance")
plt.show()
